# %% [markdown]
# # OBS Demo: A demonstration of standard-cell based obfuscation for imaging security in SKY130

# %% [markdown]
# Ckristian Duran, 2024
#
# SPDX-License-Identifier: Apache-2.0
#
# #### Team Members
#
# |Name|Affiliation|IEEE Member|SSCS Member|
# |:--:|:----------:|:----------:|:----------:|
# | Ckristian Duran (Maker) <br /> Email IDs: <br /> ckdur.iso [at] gmail [dot] com <br /> ckristian.duran [at] correo [dot] uis [dot] edu [dot] com <br /> duran [at] silicon [dot] u-tokyo [dot] ac [dot] jp|Universidad Industrial de Santander (UIS) <br /> The University of Tokyo (東京大学)| Yes |Yes |
#
# Replace `[at]` with `@`
#
# Replace `[dot]` with `.`

# %% [markdown]
# ## Abstract
#
# This project demonstrates a standard-cell based obfuscation of an example digital circuit to protect against imaging tools.
# The obfuscator works by replacing cells from a netlist by cells with identical behavior but different layout.
# This obfuscation is performed in the post-synthesis digital circuit, and the rest of the steps are executed in a typical digital composition (ej: PnR, DRC, LVS, Simulation, etc).
# The alternative cells layout do not have a significant impact in area, but the timing and capacitances can vary a little, making Static Timing Analysis vary between the original circuit and an obfuscated one.
# The cell library was previously built and characterized with enough files to perform digital synthesis and implementation.
# As part of the demo, an additional imaging-reversal procedure is built by template matching, to try to recognize back the cells in the digital circuit.
# This demo is built for Skywater 130nm (SKY130).

# %% [markdown]
# ## 1. Introduction
#
# Circuit security is a rising concern in recent years. The analysis of digital circuits to extract information has been a common ocurrence in reverse-engineering. Such analysis includes the extraction of a netlist from different stages of design and fabrication. Despite numerous intents to obscure and secretize the process in such stages, attacks always arise at the end of the production cycle. An attacker can perform decaping of a chip and perform image-reversal of a circuit in critical locations to extract information. This project is yet another way to prevent attacks from chip imaging by obfuscating the digital circuit.
#
# ### 1.1 Standard cell library
#
# The first component of this project is an standard cell library which contains the obfuscation cells. These cells contains the same circuit but contains different layouts. To exemplify this, lets take a regular NAND cell.
#
# ```spice
# * This file can be found in obs_demo/lib/sky130.lvs
# .SUBCKT ND2D1 a1 a2 vdd vss zn
# *.PININFO a1:I a2:I zn:O vdd:B vss:B
# M_M13 zn a1 xi1_n6 vss nfet_01v8 l=1.500e-07 w=6.500e-07
# M_M14 xi1_n6 a2 vss vss nfet_01v8 l=1.500e-07 w=6.500e-07
# M_M12 zn a2 vdd vdd pfet_01v8 l=1.500e-07 w=1.000e-06
# M_M11 zn a1 vdd vdd pfet_01v8 l=1.500e-07 w=1.000e-06
# .ENDS
# ```
#
# This circuit contains 4 transistors, 2 NMOS and 2 PMOS. At the moment of creating the layout, there are different ways to arrange the transistors. In the case of the NAND there are 4 possible arrangements for a minimum space layout:
#
# ```
# Arrange 1             Arrange 2          Arrange 3          Arrange 4
#        a1   a2            a1    a2         a1    a2             a1   a2
# P: vdd | z  | vdd     z   | vdd | z      z | vdd | z        vdd | z  | vdd
# N: gnd | n6 | z       gnd | n6  | z      z | n6  | gnd      z   | n6 | gnd
#        a1   a2            a1    a2         a2    a1             a2   a1
# ```
#
# With these arrangements, is possible to place and route such cells in 4 different manners in the case of the NAND
#
# ![ND2D1](assets/img/ND2D1.toon.png "NAND A.1")![ND2D1_2](assets/img/ND2D1_2.toon.png "NAND A.2")![ND2D1_3](assets/img/ND2D1_3.toon.png "NAND A.3")![ND2D1_1](assets/img/ND2D1_1.toon.png "NAND A.4")
#
# This behaviour can be extended to other cells. In the included library, the cells are limited to 4 different layouts, but this process can be repeated as many times as different arrangements are possible for a cell. This is an example of a D-Flip-Flop.
#
# ![DFQD1](assets/img/DFQD1.toon.png "DFQD1 A.1")![DFQD1_1](assets/img/DFQD1_1.toon.png "DFQD1 A.2")
#
# ![DFQD1_2](assets/img/DFQD1_2.toon.png "DFQD1 A.3")![DFQD1_3](assets/img/DFQD1_3.toon.png "DFQD1 A.4")
#
# With these cells,  a library is composed which contains combinational and sequential circuitry. Such layouts are going to be ramdomly swapped in a netlist to obfuscate the digital circuit at the moment of producing a layout.
#
# ### 1.2 Obfuscation procedure
#
# The obfuscation consists of perform synthesis, obfuscation, place, and route the circuit with the standard cell library. The next figure details the overall flow of this implementation.
#
# ![Obfuscation procedure](assets/img/obs_demo_flow.png "OBS flow")
#
# After getting a netlist of the circuit from synthesis, the obfuscation is performed to the output netlist from [yosys](https://github.com/YosysHQ/yosys).
# The script contains a link list to replace the existing cells to any of the 4 possible alternatives (if they exist).
# The cell is chosen randomly using the `obs_demo/syn/tcl/aleatorize.py` script.
# For example, an instance of `ND2D1` can be replaced by `ND2D1`, `ND2D1_1`, `ND2D1_2`, or `ND2D1_3`.
# The output of this script is a obfuscated netlist, where all the cells are replaced with equivalent circuits with theoretical different layouts.
#
# The next steps are included in the typical digital flow to output a macro layout.
# Placement, Clock Tree Synthesis (CTS) and route of the circuit is done using the obfuscated library and the geometry abstracts.
# Such process are executed with [OpenROAD](https://github.com/The-OpenROAD-Project/OpenROAD) with scripts included in the project.
# The output is a definition file which contains placement and routing of the geometry abstract, which is used by [Magic](https://github.com/RTimothyEdwards/magic) to create a final layout GDS file. DRC and LVS can be also performed at this stage.
#
# TODO: The DRC and LVS do not work at this point, as the standard cell library does not pass DRC and has connectivity issues.
#
# ### 1.3 Reverse enginering the circuit
#
# After creating the GDS layout of the digital macro, the user can perform a test for a imaging reverse-engineering of the circuit.
# Imaging tools are used to create a photo-like realistic image of the layouts of the digital macro, as well as every cell implemented in the obfuscated library.
# Afterwards, all the images are imported into a imaging reversing tool named [degate](https://github.com/DegateCommunity/Degate).
# This tool allows the user to perform imaging-reversing to a series of die photos to identify digital circuits and their netlists.
# The user can perform a template matching of the images of this demo to simulate an attack and evaluate the identification rate at a first iteration.
#
# ![Reverse test procedure](assets/img/obs_demo_rev.png "REV flow")

# %% [markdown]
# ## 2. Contents of the notebook
#
# This notebook contans an step-to-step guide to execute the [obs_demo](https://github.com/ckdur/obs_demo) project.
# In the following sections, we will describe to to the following:
#
# 1. Install tools and dependencies, working for (almost) every linux platform.
# 2. Create the obfuscated circuit, which guide the user to perform synthesis, aleatorize, place/CTS/route, and signoff of the digital macro.
# 3. Perform reverse-engineering using imaging tools, where we guide the user to perform an attack to the image of the layout, either automatically or via scripts.
#
# The demo by itself contains the following:
#
# 1. Synthesis scripts.
# 2. Aleatorize script in the synthesis container.
# 3. Place and route scripts.
# 4. Signoff scripts, including GDS creation, DRC, and LVS.
# 5. Imaging scripts to create photo-like imaging.
# 6. Reverse-engineering scripts, to execute degate with the previous images.

# %% [markdown]
# ## 3. Preparing the environment
#
# ### 3.1 Installing tools and dependencies
#
# The following code will allow you to install the dependencies from a new conda environment. Several steps can be skipped if you either installed these requirements locally in your system or in a separate conda environment you already have prepared for digital integration. The checks for these tools are automatically implemented, and this block of code can be ran just as it is.

# %%
import os
import pathlib
import sys

# We are going to use micromamba, as seems to be the most neutral to work in any environment
micromamba_path=str(pathlib.Path('micromamba').resolve())
micromamba=micromamba_path + "/bin/micromamba"
if not os.path.isfile(micromamba):
    # !mkdir -p {micromamba_path}/bin
    # !cd {micromamba_path} && curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba

# Section for checking the status of the conda installation
conda_prefix_path = os.environ.get('CONDA_PREFIX', None)
conda_exists = True
if conda_prefix_path is None:
    conda_prefix_path = str(pathlib.Path('conda-env').resolve())
    if not os.path.isdir(conda_prefix_path):
        conda_exists = False
# %env CONDA_PREFIX={conda_prefix_path}
# !mkdir -p {conda_prefix_path}/conda-meta

# Only create the environment if the conda does not exist
if not conda_exists:
    print("Create the conda environment")
    # !{micromamba} create --yes --prefix {conda_prefix_path}

# Forcing this conda environment to work with python 3.7
# !echo 'python == 3.7*' >> {conda_prefix_path}/conda-meta/pinned

# Set some environment variables
PATH = "{}/bin:{}".format(conda_prefix_path, os.environ['PATH'])  # Is supposed to not fail
LD_LIBRARY_PATH = "{0}/lib:{0}/lib/python3.7:{1}".format(conda_prefix_path, os.environ.get('LD_LIBRARY_PATH', ''))
# %env PATH={PATH}
# %env LD_LIBRARY_PATH={LD_LIBRARY_PATH}

# Now, check progressively for all the dependencies, which will list in this dict
req = {
    "magic": {"cmd": "magic --version", "channel": "main"},
    "klayout": {"cmd": "klayout -v", "channel": "main"},
    "yosys==0.36_8_g45dd9eca6": {"cmd": "yosys --version", "channel": "main"},
    "yosys-symbiflow-plugins==1.20230425_62_g0ad1af2": {"cmd": "[ -f \"$(yosys-config --datdir)/plugins/sdc.so\" ] && true || false ", "channel": "main"},
    "netgen": {"cmd": "which netgen", "channel": "main"},
    "openroad": {"cmd": "openroad -version", "channel": "main"},
    "git\\>=2.34.1": {"cmd": "git --version", "channel": "conda-forge"},
    "ruby==2.5.1": {"cmd": "false", "channel": "main"}                  # Forced, because of klayout
}
installs = list()
channels = set()
for key, elem in req.items():
    ret = os.system(elem["cmd"])
    if ret != 0:
        # This command does not exist, or does not execute. Regardless, install
        channels.add(elem["channel"])
        installs.append(key)
    else:
        # Detected. Just assume is there
        print("Detected!: {}".format(key))

install_str = " ".join(installs)
channel_str = " ".join(["--channel " + c for c in channels])
channel_print = ", ".join(channels)
print("Attempting to install from {}: {}".format(channel_print, install_str))
# !{micromamba} install --yes --prefix {conda_prefix_path} --channel litex-hub {channel_str} {install_str}

# Check exclusively for the PDK_ROOT separatelly... I wish there is a better way to check for the PDK
PDK_ROOT = os.environ.get('PDK_ROOT', None)
if PDK_ROOT is None:
    # !{micromamba} install --yes --prefix {conda_prefix_path} --channel litex-hub --channel main open_pdks.sky130a
    PDK_ROOT = "{0}/share/pdk".format(conda_prefix_path)
    # %env PDK_ROOT={PDK_ROOT}

# %% [markdown]
# ### 3.2 Download the repository
#
# The code below will download the repository where this demo is hosted.

# %%
import os
import pathlib
import sys

obs_demo_path = str(pathlib.Path('obs_demo').resolve())
obs_demo_settings = obs_demo_path + "/settings.mk"

if not os.path.isdir(obs_demo_path):
    # Download the repository
    # !git clone -b main --recursive https://github.com/ckdur/obs_demo.git {obs_demo_path}

# %env ROOT_DIR={obs_demo_path}

# %% [markdown]
# ### 3.3 Build degate
#
# This is an extra tool which is not listed in conda packages. The next block will use the repository to build Degate.

# %%
# TODO: This unfortunatelly is not possible to run in the previous conda environment. 
# REASON: qt5 and qt6 conflicts.
# WORKAROUND: We need to install another one

# Section for checking the status of the degate conda installation
degate_conda_prefix_path = os.environ.get('DEGATE_CONDA_PREFIX', None)
degate_conda_exists = True
if degate_conda_prefix_path is None:
    degate_conda_prefix_path = str(pathlib.Path('degate-conda-env').resolve())
    if not os.path.isdir(conda_prefix_path):
        degate_conda_exists = False
# %env DEGATE_CONDA_PREFIX={degate_conda_prefix_path}
# !mkdir -p {degate_conda_prefix_path}/conda-meta

# Only create the environment if the conda does not exist
if not degate_conda_exists:
    print("Create the conda environment")
    # !{micromamba} create --yes --prefix {degate_conda_prefix_path}

# Forcing this conda environment to work with python 3.7
# !echo 'python == 3.7*' >> {degate_conda_prefix_path}/conda-meta/pinned

# Set some environment variables (ohh my... this is sinful)
CONDA_PATH = "{}/bin:{}".format(degate_conda_prefix_path, os.environ['PATH'])  # Is supposed to not fail
CONDA_LD_LIBRARY_PATH = "{0}/lib:{0}/lib/python3.7:{1}".format(degate_conda_prefix_path, os.environ.get('LD_LIBRARY_PATH', ''))
# %env PATH={CONDA_PATH}
# %env LD_LIBRARY_PATH={CONDA_LD_LIBRARY_PATH}

req = {
    "pkg-config>=0.29.2": {"cmd": "false", "channel": "conda-forge"},     # FORCED
    "cmake\\>=3.22.1": {"cmd": "false", "channel": "conda-forge"},          # FORCED
    "gcc\\>=12.3.0": {"cmd": "gcc --version", "channel": "conda-forge"},
    "gxx\\>=12.3.0": {"cmd": "g++ --version", "channel": "conda-forge"},
    "qt6-main": {"cmd": "which qtdiag6", "channel": "conda-forge"}
}
installs = list()
channels = set()
for key, elem in req.items():
    ret = os.system(elem["cmd"])
    if ret != 0:
        # This command does not exist, or does not execute. Regardless, install
        channels.add(elem["channel"])
        installs.append(key)
    else:
        # Detected. Just assume is there
        print("Detected!: {}".format(key))

install_str = " ".join(installs)
channel_str = " ".join(["--channel " + c for c in channels])
channel_print = ", ".join(channels)
print("Attempting to install from {}: {}".format(channel_print, install_str))
# !{micromamba} install --yes --prefix {degate_conda_prefix_path} --channel litex-hub {channel_str} {install_str}

# !mkdir -p $ROOT_DIR/rev/src/Degate/build
# !cd $ROOT_DIR/rev/src/Degate/build && cmake $ROOT_DIR/rev/src/Degate
# !make -C $ROOT_DIR/rev/src/Degate/build all

# %% [markdown]
# ## 4. Creating the obfuscated circuit
#
# ### 4.1 Synthesis and obfuscation
#
# The synthesis uses `yosys` together with the included standard cell library to create a first netlist which the user will obfuscate later.
# The circuit under test will be an [aes core](https://github.com/secworks/aes.git).
# Configurations can be found in the `obs_demo/settings.mk`. The user is free to modify this file according to the following specifications:
#
# ```Makefile
# # Obfuscation levels. This number can be maximum 4
# LEVELS?=4
# # Recognition levels. Later used by degate to use just the plain library (1)
# # or all the cells (4). Can be maximum $(LEVELS)
# RECLEVELS?=1
#
# # Proportions of the layout. The macro will be a 4:2 ratio with 80% density in this case.
# PX?=4
# PY?=2
# PR?=0.8
#
# # When performing the imaging reversal, these are the dimmensions to analyze
# DISPX=100
# DISPY=100
# DISPW=100
# DISPH=100
#
# # TOP name of the digital circuit
# TOP?=aes
#
# # A list of verilog files for the digital circuit
# SYN_SRC?=$(ROOT_DIR)/aes/src/rtl/aes.v
# ```
#
# The following block will perform the synthesis using `yosys`. After synthesizing, the script will automatically run the `aleatorize.py` script to scramble the cells with the alternatives.

# %%
# !make -C $ROOT_DIR/syn all

# %% [markdown]
# After the user execute this command, the differences between the `obs_demo/syn/outputs/aes_net.v` and `obs_demo/syn/outputs/aes_net_obs.v` can be seen:
#
# ![Demo of the synthesis](assets/img/post_synthesis.png "Post synthesis result")

# %% [markdown]
# ### 4.2 Place and route, and signoff
#
# The place and route procedure will take the `obs_demo/syn/outputs/aes_net_obs.v` netlist and the standard cell library in the `obs_demo/lib`. To execute this, run the following:

# %%
# !make -C $ROOT_DIR/pnr all

# %% [markdown]
# After this process finishes, the user can start the signoff process.
# To create the gds, and perform DRC/LVS, please run the following cell, but note please that DRC and LVS are not passing at the moment.

# %%
# Create the GDS
# !make -C $ROOT_DIR/signoff clean
# !make -C $ROOT_DIR/signoff gds

# Perform DRC (disabled)
#!make -C $ROOT_DIR/signoff drc

# Perform LVS (disabled)
#!make -C $ROOT_DIR/signoff lvs
# Out:
# make: Entering directory '/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff'
# rm -vrf  outputs reports
# removed 'outputs/aes.gds'
# removed directory 'outputs'
# removed directory 'reports'
# make: Leaving directory '/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff'
# make: Entering directory '/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff'
# mkdir -p /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff/outputs
# mkdir -p /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff/reports
# magic -dnull -noconsole -rcfile /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/conda-env/share/pdk/sky130A/libs.tech/magic/sky130A.magicrc /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff/tcl/gds.tcl
#
# Magic 8.3 revision 462 - Compiled on Fri Feb 23 10:07:57 UTC 2024.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# Using NULL graphics device.
# Processing system .magicrc file
# Sourcing design .magicrc for technology sky130A ...
# 2 Magic internal units = 1 Lambda
# Input style sky130(): scaleFactor=2, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     ubm
# Scaled tech values by 2 / 1 to match internal grid scaling
# Loading sky130A Device Generator Menu ...
# Loading "/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff/tcl/gds.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 3.0
# Library name: sky130
# Reading "ND2D1_3".
# CIF file read warning: CIF style sky130(): units rescaled by factor of 5 / 1
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell ND2D1_3.
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND2D1_3.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND2D1_3.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND2D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND2D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND2D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND2D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND2D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND2D1_3.
# Moving label "a1" from mvvaractor to poly in cell ND2D1_3.
# Moving label "a1" from mvvaractor to polycont in cell ND2D1_3.
# Moving label "a2" from mvvaractor to poly in cell ND2D1_3.
# Moving label "a2" from mvvaractor to polycont in cell ND2D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND2D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND2D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND2D1_3.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND2D1_3.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND2D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND2D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND2D1_3.
# Reading "ND3D1".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND3D1.
# Moving label "XI1_M_u5" from mvpsubdiff to nmos in cell ND3D1.
# Moving label "XI1_M_u6" from mvpsubdiff to nmos in cell ND3D1.
# Moving label "XI1_M_u3" from mvpsubdiff to pmos in cell ND3D1.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND3D1.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND3D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND3D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1.
# Moving label "xi1_net13" from mvpsubdiff to ndiffc in cell ND3D1.
# Moving label "xi1_net13" from mvpsubdiff to ndiffc in cell ND3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND3D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1.
# Moving label "a1" from mvvaractor to poly in cell ND3D1.
# Moving label "a1" from mvvaractor to polycont in cell ND3D1.
# Moving label "a2" from mvvaractor to poly in cell ND3D1.
# Moving label "a2" from mvvaractor to polycont in cell ND3D1.
# Moving label "a3" from mvvaractor to poly in cell ND3D1.
# Moving label "a3" from mvvaractor to polycont in cell ND3D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND3D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND3D1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND3D1.
# Moving label "xi1_net13" from mvpsubdiffcont to ndiffc in cell ND3D1.
# Moving label "xi1_net13" from mvpsubdiffcont to ndiffc in cell ND3D1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND3D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND3D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1.
# Reading "ND3D1_1".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND3D1_1.
# Moving label "XI1_M_u5" from mvpsubdiff to nmos in cell ND3D1_1.
# Moving label "XI1_M_u6" from mvpsubdiff to nmos in cell ND3D1_1.
# Moving label "XI1_M_u3" from mvpsubdiff to pmos in cell ND3D1_1.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND3D1_1.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND3D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1_1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND3D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND3D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_1.
# Moving label "a1" from mvvaractor to poly in cell ND3D1_1.
# Moving label "a1" from mvvaractor to polycont in cell ND3D1_1.
# Moving label "a2" from mvvaractor to poly in cell ND3D1_1.
# Moving label "a2" from mvvaractor to polycont in cell ND3D1_1.
# Moving label "a3" from mvvaractor to poly in cell ND3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell ND3D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1_1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND3D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND3D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND3D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_1.
# Reading "ND3D1_2".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND3D1_2.
# Moving label "XI1_M_u5" from mvpsubdiff to nmos in cell ND3D1_2.
# Moving label "XI1_M_u6" from mvpsubdiff to nmos in cell ND3D1_2.
# Moving label "XI1_M_u3" from mvpsubdiff to pmos in cell ND3D1_2.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND3D1_2.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND3D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND3D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1_2.
# Moving label "xi1_net10" from mvpsubdiff to ndiffc in cell ND3D1_2.
# Moving label "xi1_net10" from mvpsubdiff to ndiffc in cell ND3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND3D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_2.
# Moving label "a1" from mvvaractor to poly in cell ND3D1_2.
# Moving label "a1" from mvvaractor to polycont in cell ND3D1_2.
# Moving label "xi1_net10" from mvvaractor to polycont in cell ND3D1_2.
# Moving label "xi1_net10" from mvvaractor to poly in cell ND3D1_2.
# Moving label "xi1_net10" from mvvaractor to polycont in cell ND3D1_2.
# Moving label "a2" from mvvaractor to poly in cell ND3D1_2.
# Moving label "a2" from mvvaractor to polycont in cell ND3D1_2.
# Moving label "a3" from mvvaractor to poly in cell ND3D1_2.
# Moving label "a3" from mvvaractor to poly in cell ND3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell ND3D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND3D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND3D1_2.
# Moving label "xi1_net10" from mvpsubdiffcont to ndiffc in cell ND3D1_2.
# Moving label "xi1_net10" from mvpsubdiffcont to ndiffc in cell ND3D1_2.
# Moving label "xi1_net10" from mvpsubdiffcont to polycont in cell ND3D1_2.
# Moving label "xi1_net10" from mvpsubdiffcont to polycont in cell ND3D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND3D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_2.
# Reading "ND3D1_3".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND3D1_3.
# Moving label "XI1_M_u5" from mvpsubdiff to nmos in cell ND3D1_3.
# Moving label "XI1_M_u6" from mvpsubdiff to nmos in cell ND3D1_3.
# Moving label "XI1_M_u3" from mvpsubdiff to pmos in cell ND3D1_3.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND3D1_3.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND3D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND3D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND3D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND3D1_3.
# Moving label "a1" from mvvaractor to poly in cell ND3D1_3.
# Moving label "a1" from mvvaractor to polycont in cell ND3D1_3.
# Moving label "a2" from mvvaractor to poly in cell ND3D1_3.
# Moving label "a2" from mvvaractor to polycont in cell ND3D1_3.
# Moving label "a3" from mvvaractor to poly in cell ND3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell ND3D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND3D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND3D1_3.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND3D1_3.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND3D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND3D1_3.
# Reading "ND4D1_1".
# Moving label "XI3" from mvpsubdiff to nmos in cell ND4D1_1.
# Moving label "XI5" from mvpsubdiff to nmos in cell ND4D1_1.
# Moving label "XI4" from mvpsubdiff to nmos in cell ND4D1_1.
# Moving label "XU53" from mvpsubdiff to nmos in cell ND4D1_1.
# Moving label "XI7" from mvpsubdiff to pmos in cell ND4D1_1.
# Moving label "XI2" from mvpsubdiff to pmos in cell ND4D1_1.
# Moving label "XI1" from mvpsubdiff to pmos in cell ND4D1_1.
# Moving label "XI0" from mvpsubdiff to pmos in cell ND4D1_1.
# Moving label "p2" from mvpsubdiff to ndiffc in cell ND4D1_1.
# Moving label "p2" from mvpsubdiff to ndiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND4D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_1.
# Moving label "a2" from mvvaractor to poly in cell ND4D1_1.
# Moving label "a2" from mvvaractor to polycont in cell ND4D1_1.
# Moving label "a4" from mvvaractor to poly in cell ND4D1_1.
# Moving label "a4" from mvvaractor to polycont in cell ND4D1_1.
# Moving label "a3" from mvvaractor to poly in cell ND4D1_1.
# Moving label "a3" from mvvaractor to polycont in cell ND4D1_1.
# Moving label "a1" from mvvaractor to poly in cell ND4D1_1.
# Moving label "a1" from mvvaractor to poly in cell ND4D1_1.
# Moving label "a1" from mvvaractor to polycont in cell ND4D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND4D1_1.
# Moving label "p2" from mvpsubdiffcont to ndiffc in cell ND4D1_1.
# Moving label "p2" from mvpsubdiffcont to ndiffc in cell ND4D1_1.
# Moving label "a4" from mvpsubdiffcont to polycont in cell ND4D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND4D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND4D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND4D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_1.
# Reading "NR2D1_2".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell NR2D1_2.
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell NR2D1_2.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell NR2D1_2.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell NR2D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR2D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR2D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR2D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR2D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR2D1_2.
# Moving label "a1" from mvvaractor to poly in cell NR2D1_2.
# Moving label "a1" from mvvaractor to polycont in cell NR2D1_2.
# Moving label "a2" from mvvaractor to poly in cell NR2D1_2.
# Moving label "a2" from mvvaractor to polycont in cell NR2D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR2D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR2D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR2D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR2D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR2D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR2D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR2D1_2.
# Reading "NR2D1_1".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell NR2D1_1.
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell NR2D1_1.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell NR2D1_1.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell NR2D1_1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR2D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR2D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR2D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR2D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR2D1_1.
# Moving label "a1" from mvvaractor to poly in cell NR2D1_1.
# Moving label "a1" from mvvaractor to polycont in cell NR2D1_1.
# Moving label "a2" from mvvaractor to poly in cell NR2D1_1.
# Moving label "a2" from mvvaractor to polycont in cell NR2D1_1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR2D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR2D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR2D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR2D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR2D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR2D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR2D1_1.
# Reading "ND4D1".
# Moving label "XI3" from mvpsubdiff to nmos in cell ND4D1.
# Moving label "XI5" from mvpsubdiff to nmos in cell ND4D1.
# Moving label "XI4" from mvpsubdiff to nmos in cell ND4D1.
# Moving label "XU53" from mvpsubdiff to nmos in cell ND4D1.
# Moving label "XI7" from mvpsubdiff to pmos in cell ND4D1.
# Moving label "XI2" from mvpsubdiff to pmos in cell ND4D1.
# Moving label "XI1" from mvpsubdiff to pmos in cell ND4D1.
# Moving label "XI0" from mvpsubdiff to pmos in cell ND4D1.
# Moving label "p1" from mvpsubdiff to ndiffc in cell ND4D1.
# Moving label "p1" from mvpsubdiff to ndiffc in cell ND4D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND4D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1.
# Moving label "a2" from mvvaractor to poly in cell ND4D1.
# Moving label "a2" from mvvaractor to polycont in cell ND4D1.
# Moving label "a4" from mvvaractor to poly in cell ND4D1.
# Moving label "a4" from mvvaractor to polycont in cell ND4D1.
# Moving label "a3" from mvvaractor to poly in cell ND4D1.
# Moving label "a3" from mvvaractor to polycont in cell ND4D1.
# Moving label "a1" from mvvaractor to poly in cell ND4D1.
# Moving label "a1" from mvvaractor to polycont in cell ND4D1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND4D1.
# Moving label "p1" from mvpsubdiffcont to ndiffc in cell ND4D1.
# Moving label "p1" from mvpsubdiffcont to ndiffc in cell ND4D1.
# Moving label "a4" from mvpsubdiffcont to polycont in cell ND4D1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND4D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND4D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND4D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1.
# Reading "ND4D1_3".
# Moving label "XI3" from mvpsubdiff to nmos in cell ND4D1_3.
# Moving label "XI5" from mvpsubdiff to nmos in cell ND4D1_3.
# Moving label "XI4" from mvpsubdiff to nmos in cell ND4D1_3.
# Moving label "XU53" from mvpsubdiff to nmos in cell ND4D1_3.
# Moving label "XI7" from mvpsubdiff to pmos in cell ND4D1_3.
# Moving label "XI2" from mvpsubdiff to pmos in cell ND4D1_3.
# Moving label "XI1" from mvpsubdiff to pmos in cell ND4D1_3.
# Moving label "XI0" from mvpsubdiff to pmos in cell ND4D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND4D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND4D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_3.
# Moving label "a2" from mvvaractor to poly in cell ND4D1_3.
# Moving label "a2" from mvvaractor to polycont in cell ND4D1_3.
# Moving label "a4" from mvvaractor to poly in cell ND4D1_3.
# Moving label "a4" from mvvaractor to polycont in cell ND4D1_3.
# Moving label "a3" from mvvaractor to poly in cell ND4D1_3.
# Moving label "a3" from mvvaractor to polycont in cell ND4D1_3.
# Moving label "a1" from mvvaractor to poly in cell ND4D1_3.
# Moving label "a1" from mvvaractor to polycont in cell ND4D1_3.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND4D1_3.
# Moving label "a4" from mvpsubdiffcont to polycont in cell ND4D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND4D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND4D1_3.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND4D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND4D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_3.
# Reading "ND4D1_2".
# Moving label "XI3" from mvpsubdiff to nmos in cell ND4D1_2.
# Moving label "XI5" from mvpsubdiff to nmos in cell ND4D1_2.
# Moving label "XI4" from mvpsubdiff to nmos in cell ND4D1_2.
# Moving label "XU53" from mvpsubdiff to nmos in cell ND4D1_2.
# Moving label "XI7" from mvpsubdiff to pmos in cell ND4D1_2.
# Moving label "XI2" from mvpsubdiff to pmos in cell ND4D1_2.
# Moving label "XI1" from mvpsubdiff to pmos in cell ND4D1_2.
# Moving label "XI0" from mvpsubdiff to pmos in cell ND4D1_2.
# Moving label "p0" from mvpsubdiff to ndiffc in cell ND4D1_2.
# Moving label "p0" from mvpsubdiff to ndiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND4D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND4D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND4D1_2.
# Moving label "p0" from mvvaractor to polycont in cell ND4D1_2.
# Moving label "p0" from mvvaractor to poly in cell ND4D1_2.
# Moving label "p0" from mvvaractor to polycont in cell ND4D1_2.
# Moving label "a2" from mvvaractor to poly in cell ND4D1_2.
# Moving label "a2" from mvvaractor to polycont in cell ND4D1_2.
# Moving label "a4" from mvvaractor to poly in cell ND4D1_2.
# Moving label "a4" from mvvaractor to polycont in cell ND4D1_2.
# Moving label "a3" from mvvaractor to poly in cell ND4D1_2.
# Moving label "a3" from mvvaractor to polycont in cell ND4D1_2.
# Moving label "a1" from mvvaractor to poly in cell ND4D1_2.
# Moving label "a1" from mvvaractor to polycont in cell ND4D1_2.
# Moving label "p0" from mvpsubdiffcont to ndiffc in cell ND4D1_2.
# Moving label "p0" from mvpsubdiffcont to ndiffc in cell ND4D1_2.
# Moving label "p0" from mvpsubdiffcont to polycont in cell ND4D1_2.
# Moving label "p0" from mvpsubdiffcont to polycont in cell ND4D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND4D1_2.
# Moving label "a4" from mvpsubdiffcont to polycont in cell ND4D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell ND4D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND4D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND4D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND4D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND4D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND4D1_2.
# Reading "NR2D1".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell NR2D1.
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell NR2D1.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell NR2D1.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell NR2D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR2D1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR2D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR2D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR2D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR2D1.
# Moving label "a1" from mvvaractor to poly in cell NR2D1.
# Moving label "a1" from mvvaractor to polycont in cell NR2D1.
# Moving label "a2" from mvvaractor to poly in cell NR2D1.
# Moving label "a2" from mvvaractor to polycont in cell NR2D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR2D1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR2D1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR2D1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR2D1.
# Reading "NR2D1_3".
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell NR2D1_3.
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell NR2D1_3.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell NR2D1_3.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell NR2D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR2D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR2D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR2D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR2D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR2D1_3.
# Moving label "a1" from mvvaractor to poly in cell NR2D1_3.
# Moving label "a1" from mvvaractor to polycont in cell NR2D1_3.
# Moving label "a2" from mvvaractor to poly in cell NR2D1_3.
# Moving label "a2" from mvvaractor to polycont in cell NR2D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR2D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR2D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR2D1_3.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR2D1_3.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR2D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR2D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR2D1_3.
# Reading "NR3D1_3".
# Moving label "X_u4" from mvpsubdiff to nmos in cell NR3D1_3.
# Moving label "XI2" from mvpsubdiff to nmos in cell NR3D1_3.
# Moving label "XI3" from mvpsubdiff to nmos in cell NR3D1_3.
# Moving label "XI4_0" from mvpsubdiff to pmos in cell NR3D1_3.
# Moving label "X_u1_0" from mvpsubdiff to pmos in cell NR3D1_3.
# Moving label "X_u1_1" from mvpsubdiff to pmos in cell NR3D1_3.
# Moving label "XI4_1" from mvpsubdiff to pmos in cell NR3D1_3.
# Moving label "XI5_0" from mvpsubdiff to pmos in cell NR3D1_3.
# Moving label "XI5_1" from mvpsubdiff to pmos in cell NR3D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "net34_0_" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "net34_0_" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1_3.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a3" from mvvaractor to pmos in cell NR3D1_3.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a3" from mvvaractor to pmos in cell NR3D1_3.
# Moving label "a3" from mvvaractor to nmos in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a2" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a2" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a2" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1_3.
# Moving label "a1" from mvvaractor to nmos in cell NR3D1_3.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "a1" from mvvaractor to pmos in cell NR3D1_3.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_3.
# Moving label "a1" from mvvaractor to pmos in cell NR3D1_3.
# Moving label "net34_0_" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "net34_0_" from mvvaractor to poly in cell NR3D1_3.
# Moving label "net34_0_" from mvvaractor to polycont in cell NR3D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "net37_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "net37_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "net34_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "net34_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "net34_0_" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "net34_0_" from mvpsubdiffcont to polycont in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR3D1_3.
# Reading "NR3D1_2".
# Moving label "X_u4" from mvpsubdiff to nmos in cell NR3D1_2.
# Moving label "XI2" from mvpsubdiff to nmos in cell NR3D1_2.
# Moving label "XI3" from mvpsubdiff to nmos in cell NR3D1_2.
# Moving label "XI4_0" from mvpsubdiff to pmos in cell NR3D1_2.
# Moving label "X_u1_0" from mvpsubdiff to pmos in cell NR3D1_2.
# Moving label "X_u1_1" from mvpsubdiff to pmos in cell NR3D1_2.
# Moving label "XI4_1" from mvpsubdiff to pmos in cell NR3D1_2.
# Moving label "XI5_0" from mvpsubdiff to pmos in cell NR3D1_2.
# Moving label "XI5_1" from mvpsubdiff to pmos in cell NR3D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "net34_1_" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "net34_1_" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1_2.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a3" from mvvaractor to pmos in cell NR3D1_2.
# Moving label "a3" from mvvaractor to nmos in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a3" from mvvaractor to nmos in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a2" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1_2.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1_2.
# Moving label "a1" from mvvaractor to pmos in cell NR3D1_2.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_2.
# Moving label "a1" from mvvaractor to nmos in cell NR3D1_2.
# Moving label "a1" from mvvaractor to pmos in cell NR3D1_2.
# Moving label "net37_0_" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "net37_0_" from mvvaractor to poly in cell NR3D1_2.
# Moving label "net37_0_" from mvvaractor to polycont in cell NR3D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "net37_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "net37_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "net37_0_" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "net37_0_" from mvpsubdiffcont to polycont in cell NR3D1_2.
# Moving label "net34_1_" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "net34_1_" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR3D1_2.
# Reading "NR3D1_1".
# Moving label "X_u4" from mvpsubdiff to nmos in cell NR3D1_1.
# Moving label "XI2" from mvpsubdiff to nmos in cell NR3D1_1.
# Moving label "XI3" from mvpsubdiff to nmos in cell NR3D1_1.
# Moving label "XI4_0" from mvpsubdiff to pmos in cell NR3D1_1.
# Moving label "X_u1_0" from mvpsubdiff to pmos in cell NR3D1_1.
# Moving label "X_u1_1" from mvpsubdiff to pmos in cell NR3D1_1.
# Moving label "XI4_1" from mvpsubdiff to pmos in cell NR3D1_1.
# Moving label "XI5_0" from mvpsubdiff to pmos in cell NR3D1_1.
# Moving label "XI5_1" from mvpsubdiff to pmos in cell NR3D1_1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net34_0_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net34_0_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net34_1_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net34_1_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net37_1_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "net37_1_" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1_1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a3" from mvvaractor to pmos in cell NR3D1_1.
# Moving label "a3" from mvvaractor to nmos in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a3" from mvvaractor to nmos in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a2" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1_1.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1_1.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a1" from mvvaractor to poly in cell NR3D1_1.
# Moving label "a1" from mvvaractor to pmos in cell NR3D1_1.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "net34_0_" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "net34_0_" from mvvaractor to poly in cell NR3D1_1.
# Moving label "net34_0_" from mvvaractor to polycont in cell NR3D1_1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a3" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "net37_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net37_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net34_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net34_0_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net34_0_" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "net34_0_" from mvpsubdiffcont to polycont in cell NR3D1_1.
# Moving label "net34_1_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net34_1_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net37_1_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "net37_1_" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell NR3D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell NR3D1_1.
# Reading "NR3D1".
# Moving label "X_u4" from mvpsubdiff to nmos in cell NR3D1.
# Moving label "XI2" from mvpsubdiff to nmos in cell NR3D1.
# Moving label "XI3" from mvpsubdiff to nmos in cell NR3D1.
# Moving label "XI4_0" from mvpsubdiff to pmos in cell NR3D1.
# Moving label "X_u1_0" from mvpsubdiff to pmos in cell NR3D1.
# Moving label "X_u1_1" from mvpsubdiff to pmos in cell NR3D1.
# Moving label "XI4_1" from mvpsubdiff to pmos in cell NR3D1.
# Moving label "XI5_0" from mvpsubdiff to pmos in cell NR3D1.
# Moving label "XI5_1" from mvpsubdiff to pmos in cell NR3D1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "net37_0_" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "net34_0_" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "net34_0_" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "net34_1_" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "net34_1_" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell NR3D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to pmos in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a3" from mvvaractor to poly in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a3" from mvvaractor to polycont in cell NR3D1.
# Moving label "a2" from mvvaractor to poly in cell NR3D1.
# Moving label "a2" from mvvaractor to poly in cell NR3D1.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1.
# Moving label "a2" from mvvaractor to polycont in cell NR3D1.
# Moving label "a2" from mvvaractor to pmos in cell NR3D1.
# Moving label "a1" from mvvaractor to poly in cell NR3D1.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1.
# Moving label "a1" from mvvaractor to polycont in cell NR3D1.
# Moving label "a1" from mvvaractor to nmos in cell NR3D1.
# Moving label "a1" from mvvaractor to poly in cell NR3D1.
# Moving label "a1" from mvvaractor to pmos in cell NR3D1.
# Moving label "net34_0_" from mvvaractor to polycont in cell NR3D1.
# Moving label "net34_0_" from mvvaractor to poly in cell NR3D1.
# Moving label "net34_0_" from mvvaractor to polycont in cell NR3D1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell NR3D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell NR3D1.
# ...
# Moving label "net42" from mvpsubdiffcont to polycont in cell MUX2D1.
# Moving label "net42" from mvpsubdiffcont to polycont in cell MUX2D1.
# Moving label "i1" from mvpsubdiffcont to polycont in cell MUX2D1.
# Moving label "i0" from mvpsubdiffcont to polycont in cell MUX2D1.
# Moving label "z" from mvpsubdiffcont to ndiffc in cell MUX2D1.
# Moving label "z" from mvpsubdiffcont to pdiffc in cell MUX2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell MUX2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell MUX2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell MUX2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell MUX2D1.
# Reading "ND2D1".
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell ND2D1.
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND2D1.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND2D1.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND2D1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND2D1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND2D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND2D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND2D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND2D1.
# Moving label "a1" from mvvaractor to poly in cell ND2D1.
# Moving label "a1" from mvvaractor to polycont in cell ND2D1.
# Moving label "a2" from mvvaractor to poly in cell ND2D1.
# Moving label "a2" from mvvaractor to polycont in cell ND2D1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND2D1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND2D1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND2D1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND2D1.
# Reading "ND2D1_1".
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell ND2D1_1.
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND2D1_1.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND2D1_1.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND2D1_1.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND2D1_1.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND2D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND2D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND2D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND2D1_1.
# Moving label "a1" from mvvaractor to poly in cell ND2D1_1.
# Moving label "a1" from mvvaractor to polycont in cell ND2D1_1.
# Moving label "a2" from mvvaractor to poly in cell ND2D1_1.
# Moving label "a2" from mvvaractor to polycont in cell ND2D1_1.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND2D1_1.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND2D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND2D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND2D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND2D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND2D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND2D1_1.
# Reading "ND2D1_2".
# Moving label "XI1_M_u3" from mvpsubdiff to nmos in cell ND2D1_2.
# Moving label "XI1_M_u4" from mvpsubdiff to nmos in cell ND2D1_2.
# Moving label "XI1_M_u2" from mvpsubdiff to pmos in cell ND2D1_2.
# Moving label "XI1_M_u1" from mvpsubdiff to pmos in cell ND2D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND2D1_2.
# Moving label "zn" from mvpsubdiff to ndiffc in cell ND2D1_2.
# Moving label "zn" from mvpsubdiff to pdiffc in cell ND2D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell ND2D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell ND2D1_2.
# Moving label "a1" from mvvaractor to poly in cell ND2D1_2.
# Moving label "a1" from mvvaractor to poly in cell ND2D1_2.
# Moving label "a1" from mvvaractor to polycont in cell ND2D1_2.
# Moving label "a2" from mvvaractor to poly in cell ND2D1_2.
# Moving label "a2" from mvvaractor to polycont in cell ND2D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND2D1_2.
# Moving label "zn" from mvpsubdiffcont to ndiffc in cell ND2D1_2.
# Moving label "zn" from mvpsubdiffcont to pdiffc in cell ND2D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell ND2D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell ND2D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell ND2D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell ND2D1_2.
# Reading "(UNNAMED)".
# Warning:  cell (UNNAMED) already existed before reading GDS!
# Reading "AN2D1".
# Moving label "X_u2_M_u3" from mvpsubdiff to nmos in cell AN2D1.
# Moving label "X_u3_M_u2" from mvpsubdiff to nmos in cell AN2D1.
# Moving label "X_u2_M_u4" from mvpsubdiff to nmos in cell AN2D1.
# Moving label "X_u3_M_u3" from mvpsubdiff to pmos in cell AN2D1.
# Moving label "X_u2_M_u2" from mvpsubdiff to pmos in cell AN2D1.
# Moving label "X_u2_M_u1" from mvpsubdiff to pmos in cell AN2D1.
# Moving label "net6" from mvpsubdiff to pdiffc in cell AN2D1.
# Moving label "net6" from mvpsubdiff to ndiffc in cell AN2D1.
# Moving label "z" from mvpsubdiff to ndiffc in cell AN2D1.
# Moving label "z" from mvpsubdiff to pdiffc in cell AN2D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell AN2D1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell AN2D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1.
# Moving label "net6" from mvvaractor to polycont in cell AN2D1.
# Moving label "net6" from mvvaractor to poly in cell AN2D1.
# Moving label "net6" from mvvaractor to poly in cell AN2D1.
# Moving label "net6" from mvvaractor to poly in cell AN2D1.
# Moving label "a1" from mvvaractor to poly in cell AN2D1.
# Moving label "a1" from mvvaractor to polycont in cell AN2D1.
# Moving label "a2" from mvvaractor to poly in cell AN2D1.
# Moving label "a2" from mvvaractor to polycont in cell AN2D1.
# Moving label "net6" from mvpsubdiffcont to pdiffc in cell AN2D1.
# Moving label "net6" from mvpsubdiffcont to ndiffc in cell AN2D1.
# Moving label "net6" from mvpsubdiffcont to polycont in cell AN2D1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell AN2D1.
# Moving label "z" from mvpsubdiffcont to ndiffc in cell AN2D1.
# Moving label "z" from mvpsubdiffcont to pdiffc in cell AN2D1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell AN2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell AN2D1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell AN2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1.
# Reading "AN2D1_1".
# Moving label "X_u2_M_u3" from mvpsubdiff to nmos in cell AN2D1_1.
# Moving label "X_u3_M_u2" from mvpsubdiff to nmos in cell AN2D1_1.
# Moving label "X_u2_M_u4" from mvpsubdiff to nmos in cell AN2D1_1.
# Moving label "X_u3_M_u3" from mvpsubdiff to pmos in cell AN2D1_1.
# Moving label "X_u2_M_u2" from mvpsubdiff to pmos in cell AN2D1_1.
# Moving label "X_u2_M_u1" from mvpsubdiff to pmos in cell AN2D1_1.
# Moving label "net6" from mvpsubdiff to ndiffc in cell AN2D1_1.
# Moving label "net6" from mvpsubdiff to pdiffc in cell AN2D1_1.
# Moving label "z" from mvpsubdiff to ndiffc in cell AN2D1_1.
# Moving label "z" from mvpsubdiff to pdiffc in cell AN2D1_1.
# Moving label "vss" from mvpsubdiff to ndiffc in cell AN2D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1_1.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1_1.
# Moving label "net6" from mvvaractor to polycont in cell AN2D1_1.
# Moving label "net6" from mvvaractor to pmos in cell AN2D1_1.
# Moving label "net6" from mvvaractor to poly in cell AN2D1_1.
# Moving label "a1" from mvvaractor to poly in cell AN2D1_1.
# Moving label "a1" from mvvaractor to polycont in cell AN2D1_1.
# Moving label "a2" from mvvaractor to poly in cell AN2D1_1.
# Moving label "a2" from mvvaractor to polycont in cell AN2D1_1.
# Moving label "net6" from mvpsubdiffcont to ndiffc in cell AN2D1_1.
# Moving label "net6" from mvpsubdiffcont to pdiffc in cell AN2D1_1.
# Moving label "net6" from mvpsubdiffcont to polycont in cell AN2D1_1.
# Moving label "a1" from mvpsubdiffcont to polycont in cell AN2D1_1.
# Moving label "z" from mvpsubdiffcont to ndiffc in cell AN2D1_1.
# Moving label "z" from mvpsubdiffcont to pdiffc in cell AN2D1_1.
# Moving label "a2" from mvpsubdiffcont to polycont in cell AN2D1_1.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell AN2D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1_1.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1_1.
# Reading "AN2D1_2".
# Moving label "X_u2_M_u3" from mvpsubdiff to nmos in cell AN2D1_2.
# Moving label "X_u3_M_u2" from mvpsubdiff to nmos in cell AN2D1_2.
# Moving label "X_u2_M_u4" from mvpsubdiff to nmos in cell AN2D1_2.
# Moving label "X_u3_M_u3" from mvpsubdiff to pmos in cell AN2D1_2.
# Moving label "X_u2_M_u2" from mvpsubdiff to pmos in cell AN2D1_2.
# Moving label "X_u2_M_u1" from mvpsubdiff to pmos in cell AN2D1_2.
# Moving label "net6" from mvpsubdiff to pdiffc in cell AN2D1_2.
# Moving label "net6" from mvpsubdiff to ndiffc in cell AN2D1_2.
# Moving label "net6" from mvpsubdiff to pdiffc in cell AN2D1_2.
# Moving label "z" from mvpsubdiff to ndiffc in cell AN2D1_2.
# Moving label "z" from mvpsubdiff to pdiffc in cell AN2D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell AN2D1_2.
# Moving label "vss" from mvpsubdiff to ndiffc in cell AN2D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1_2.
# Moving label "vdd" from mvpsubdiff to pdiffc in cell AN2D1_2.
# Moving label "net6" from mvvaractor to polycont in cell AN2D1_2.
# Moving label "net6" from mvvaractor to poly in cell AN2D1_2.
# Moving label "net6" from mvvaractor to poly in cell AN2D1_2.
# Moving label "net6" from mvvaractor to polycont in cell AN2D1_2.
# Moving label "net6" from mvvaractor to poly in cell AN2D1_2.
# Moving label "net6" from mvvaractor to pmos in cell AN2D1_2.
# Moving label "a1" from mvvaractor to poly in cell AN2D1_2.
# Moving label "a1" from mvvaractor to polycont in cell AN2D1_2.
# Moving label "a2" from mvvaractor to poly in cell AN2D1_2.
# Moving label "a2" from mvvaractor to polycont in cell AN2D1_2.
# Moving label "net6" from mvpsubdiffcont to pdiffc in cell AN2D1_2.
# Moving label "net6" from mvpsubdiffcont to ndiffc in cell AN2D1_2.
# Moving label "net6" from mvpsubdiffcont to pdiffc in cell AN2D1_2.
# Moving label "net6" from mvpsubdiffcont to polycont in cell AN2D1_2.
# Moving label "net6" from mvpsubdiffcont to polycont in cell AN2D1_2.
# Moving label "a1" from mvpsubdiffcont to polycont in cell AN2D1_2.
# Moving label "z" from mvpsubdiffcont to ndiffc in cell AN2D1_2.
# Moving label "z" from mvpsubdiffcont to pdiffc in cell AN2D1_2.
# Moving label "a2" from mvpsubdiffcont to polycont in cell AN2D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell AN2D1_2.
# Moving label "vss" from mvpsubdiffcont to ndiffc in cell AN2D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1_2.
# Moving label "vdd" from mvpsubdiffcont to pdiffc in cell AN2D1_2.
# Reading LEF data from file /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/lib/sky130.tlef.
# This action cannot be undone.
# LEF read, Line 88 (Message): Unknown keyword "ANTENNAMODEL" in LEF file; ignoring.
# LEF read, Line 89 (Message): Unknown keyword "ANTENNADIFFSIDEAREARATIO" in LEF file; ignoring.
# LEF read, Line 122 (Message): Unknown keyword "MINENCLOSEDAREA" in LEF file; ignoring.
# LEF read, Line 124 (Message): Unknown keyword "ANTENNAMODEL" in LEF file; ignoring.
# LEF read, Line 125 (Message): Unknown keyword "ANTENNADIFFSIDEAREARATIO" in LEF file; ignoring.
# LEF read, Line 131 (Message): Unknown keyword "MAXIMUMDENSITY" in LEF file; ignoring.
# LEF read, Line 132 (Message): Unknown keyword "DENSITYCHECKWINDOW" in LEF file; ignoring.
# LEF read, Line 133 (Message): Unknown keyword "DENSITYCHECKSTEP" in LEF file; ignoring.
# LEF read, Line 166 (Message): Unknown keyword "MINENCLOSEDAREA" in LEF file; ignoring.
# LEF read, Line 174 (Message): Unknown keyword "ANTENNAMODEL" in LEF file; ignoring.
# LEF read, Line 175 (Message): Unknown keyword "ANTENNADIFFSIDEAREARATIO" in LEF file; ignoring.
# LEF read, Line 177 (Message): Unknown keyword "MAXIMUMDENSITY" in LEF file; ignoring.
# LEF read, Line 178 (Message): Unknown keyword "DENSITYCHECKWINDOW" in LEF file; ignoring.
# LEF read, Line 179 (Message): Unknown keyword "DENSITYCHECKSTEP" in LEF file; ignoring.
# LEF read, Line 216 (Message): Unknown keyword "ANTENNAMODEL" in LEF file; ignoring.
# LEF read, Line 217 (Message): Unknown keyword "ANTENNADIFFSIDEAREARATIO" in LEF file; ignoring.
# LEF read, Line 219 (Message): Unknown keyword "MAXIMUMDENSITY" in LEF file; ignoring.
# LEF read, Line 220 (Message): Unknown keyword "DENSITYCHECKWINDOW" in LEF file; ignoring.
# LEF read, Line 221 (Message): Unknown keyword "DENSITYCHECKSTEP" in LEF file; ignoring.
# LEF read, Line 258 (Message): Unknown keyword "ANTENNAMODEL" in LEF file; ignoring.
# LEF read, Line 259 (Message): Unknown keyword "ANTENNADIFFSIDEAREARATIO" in LEF file; ignoring.
# LEF read, Line 261 (Message): Unknown keyword "MAXIMUMDENSITY" in LEF file; ignoring.
# LEF read, Line 262 (Message): Unknown keyword "DENSITYCHECKWINDOW" in LEF file; ignoring.
# LEF read, Line 263 (Message): Unknown keyword "DENSITYCHECKSTEP" in LEF file; ignoring.
# LEF read, Line 300 (Message): Unknown keyword "ANTENNAMODEL" in LEF file; ignoring.
# LEF read, Line 301 (Message): Unknown keyword "ANTENNADIFFSIDEAREARATIO" in LEF file; ignoring.
# LEF read: Processed 807 lines.
# Reading DEF data from file /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/pnr/outputs/aes.def.
# This action cannot be undone.
#   Processed 6 vias total.
#   Processed 19274 subcell instances total.
#   Processed 78 pins total.
#   Processed 2 special nets total.
#   Processed 19318 nets total.
# DEF read: Processed 134930 lines.
#    Generating output for cell AN2D1
#    Generating output for cell MUX2D1_3
#    Generating output for cell DFCNQD1_2
#    Generating output for cell DFCNQD1_1
#    Generating output for cell MUX2D1_2
#    Generating output for cell AN2D1_3
#    Generating output for cell MUX2D1_1
#    Generating output for cell AO21D1
#    Generating output for cell DFCNQD1_3
#    Generating output for cell MUX2D1
#    Generating output for cell AN2D1_1
#    Generating output for cell DFCNQD1
#    Generating output for cell AOI21D1_3
#    Generating output for cell AO21D1_3
#    Generating output for cell AOI21D1_2
#    Generating output for cell AOI21D1_1
#    Generating output for cell AN2D1_2
#    Generating output for cell AO21D1_2
#    Generating output for cell NR4D1
#    Generating output for cell NR3D1
#    Generating output for cell NR2D1_2
#    Generating output for cell OR2D1
#    Generating output for cell ND2D1_3
#    Generating output for cell ND3D1
#    Generating output for cell NR2D1
#    Generating output for cell ND2D1_2
#    Generating output for cell ND4D1
#    Generating output for cell BUFFD1
#    Generating output for cell ND2D1
#    Generating output for cell OAI21D1_2
#    Generating output for cell AOI21D1
#    Generating output for cell AO21D1_1
#    Generating output for cell OA21D1_2
#    Generating output for cell OA21D1
#    Generating output for cell OAI21D1_3
#    Generating output for cell ND2D1_1
#    Generating output for cell OAI21D1
#    Generating output for cell NR2D1_3
#    Generating output for cell OR2D1_1
#    Generating output for cell NR2D1_1
#    Generating output for cell OR2D1_2
#    Generating output for cell OA21D1_1
#    Generating output for cell OAI21D1_1
#    Generating output for cell OA21D1_3
#    Generating output for cell OR2D1_3
#    Generating output for cell XOR2D1
#    Generating output for cell XNR2D1
#    Generating output for cell INVD1
#    Generating output for cell aes

# %% [markdown]
# ## 5. Reverse-engineering the circuit
#
# To demonstrate the obfuscation impact in the circuit, the next steps are going to demonstrate an hypotetical scenario where the attacker extracts images from a chip and perform an imaging attack. This process is accomplished by creating photo-like images of each one of the standard cells, and also an image of the overall circuit.
#
# ### 5.1 Imaging the circuits
#
# This step involves the conversion from the layouts of both standard cells and the top module. The next cell will take the GDS file of each of those circuits and extract images. The procedure is as following:
#
# 1. Use klayout with an special layer file to color the layout with a different pallete that resembles more the post-fabrication.
# 2. Add different kinds of image manipulation using GIMP to add some texture and 3D effects.
# 3. Convert the output of all the post-effect GIMP images into different TIF images which can be fed into degate.

# %%
# Make the TOP photo-like
# !make -C $ROOT_DIR/images top_real
# Out:
# make: Entering directory '/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images'
# mkdir -p /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images/real_4
# klayout -z -r make_real.py -rd top=aes -rd infile=/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/signoff/outputs/aes.gds -rd outfile=/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images/real_4/aes.real.png -rd outtranfile=/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images/real_4/aes.tran.png -rd outmetfile=/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images/real_4/aes.met.png -rd techname=sky130 -rd dispw=100 -rd disph=100 -rd dispx=100 -rd dispy=100
# ERROR: RuntimeError: Unexpected end-of-file (position=1859584, record number=211049, cell=aes) in LayoutViewBase.load_layout
#   make_real.py:23
# make: *** [Makefile:72: /home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images/real_4/aes.r.full.tif] Error 1
# make: Leaving directory '/home/duran/Documents/sscs-ose-code-a-chip.github.io/VLSI24/submitted_notebooks/obs_demo/obs_demo/images'

# %% [markdown]
# In the case of the standard cells, we extract some additional features from the ports of the standard cells. This process is necessary to detect interconnections in the future to extract a netlist.

# %%
# Make the standard cells photo-like, and also create the library definition for degate
# !make -C $ROOT_DIR/images lib_real
# !make -C $ROOT_DIR/images lib_out

# %% [markdown]
# ### 5.2 Setup the attack

# %% [markdown]
# ### 5.3 Judging the success of the attack

# %% [markdown]
# ## 6. Conclusions and acknoledgements
#
# This project implemented a digital circuit example (an aes core) with an obfuscation that involves an special standard cell library.
# This standard cell library contains different layouts of the same circuit.
# With this approach, the project is able to mitigate image-reversing of the circuit.
# The concept is partially proven by creating photo-like images of the layouts and the standard cells.
# Such images are fed into a image-reversing tool named `degate` which performs correlation detection in the different photos.
# If we suppose the attacker only has knoledge of the basic standard cell library, the attack is only successful around the 20% of the total circuitry.
#
# The project was possible thanks to the usage of an standard cell generator developed in the "Universidad Industrial de Santander" (Insdustrial University of Santander) in Colombia/Bucaramanga.
# I also want to acknoledge my current job at the University of Tokyo.
