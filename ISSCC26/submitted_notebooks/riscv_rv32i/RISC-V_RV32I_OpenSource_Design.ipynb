# %% [markdown]
# # RISC-V RV32I Processor Design using OpenLane
#
# **Name:** Harshitha
# **Project:** 32-bit RISC-V CPU (RV32I Subset)

# %% [markdown]
# This project implements a basic RISC-V RV32I processor including:
# - ALU
# - Register File
# - Instruction Decoder
#
# The design is verified using simulation and synthesized using OpenLane.

# %% [markdown]
# ## Project Overview
#
# This project implements a basic 32-bit RISC-V (RV32I) processor.
#
# ### Key Components:
# - ALU (Arithmetic Logic Unit)
# - Register File
# - Instruction Decoder
#
# ### Supported Instructions:
# - ADD, SUB
# - AND, OR, XOR
# - ADDI, ANDI, ORI

# %% [markdown]
# ## Functional Simulation
#
# The design is verified using Icarus Verilog (iverilog) and simulated using vvp.
#
# The following instructions were tested:
# - ADDI
# - ADD
# - SUB
# - AND, OR, XOR

# %%
# !iverilog -o sim.out tb/tb_riscv_rv32i.v src/riscv_rv32i.v src/alu.v src/regfile.v src/decoder.v
# !vvp sim.out

# %% [markdown]
# ### Simulation Result
#
# The simulation output confirms correct execution of all instructions.
#
# All expected results match the computed outputs.

# %% [markdown]
# ## Waveform Analysis
#
# The waveform was analyzed using GTKWave.
#
# Key signals observed:
# - clk
# - instr
# - alu_result
# - register outputs
#
# The waveform confirms correct data flow between modules.

# %% [markdown]
# ## Physical Design using OpenLane
#
# The RTL design was synthesized and implemented using OpenLane with SKY130 PDK.
#
# Steps:
# - Synthesis
# - Floorplanning
# - Placement
# - Clock Tree Synthesis
# - Routing

# %%
./flow.tcl -design riscv_rv32i

# %% [markdown]
# ## Static Timing Analysis (STA)
#
# Timing analysis was performed after synthesis and placement.
#
# The design meets timing constraints under the given conditions.

# %% [markdown]
# ## GDSII Layout
#
# Final layout generated using OpenLane.
#
# This represents the physical implementation of the RISC-V processor.
